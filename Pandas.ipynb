# %%
# !pip install Pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install Numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !wget https://raw.githubusercontent.com/CodexploreRepo/data-science/main/Code/A2_Pandas/P1_Getting_Knowing_Data/chipotle.tsv
# Out:
# --2023-04-14 19:07:04--  https://raw.githubusercontent.com/CodexploreRepo/data-science/main/Code/A2_Pandas/P1_Getting_Knowing_Data/chipotle.tsv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 364975 (356K) [text/plain]
# Saving to: ‘chipotle.tsv’
#
# chipotle.tsv        100%[===================>] 356.42K  --.-KB/s    in 0.02s
#
# 2023-04-14 19:07:04 (15.8 MB/s) - ‘chipotle.tsv’ saved [364975/364975]

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('chipotle.tsv', sep='\t')

# %%
df.head(6)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.describe(include='all')
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
df.loc[(df.quantity==2)&(df.item_name=='Chicken Bowl'),['order_id','quantity','item_name','item_price']]
# Out:
#       order_id  quantity     item_name item_price
# 4            2         2  Chicken Bowl    $16.98
# 154         70         2  Chicken Bowl    $17.50
# 282        124         2  Chicken Bowl    $17.50
# 415        181         2  Chicken Bowl    $17.50
# 654        271         2  Chicken Bowl    $17.50
# 976        401         2  Chicken Bowl    $17.50
# 1017       418         2  Chicken Bowl    $17.50
# 1106       457         2  Chicken Bowl    $17.50
# 1429       578         2  Chicken Bowl    $22.50
# 1588       643         2  Chicken Bowl    $17.50
# 1832       741         2  Chicken Bowl    $21.96
# 2075       837         2  Chicken Bowl    $21.96
# 2106       848         2  Chicken Bowl    $17.50
# 2339       932         2  Chicken Bowl    $16.98
# 2510       997         2  Chicken Bowl    $22.50
# 2525      1004         2  Chicken Bowl    $21.96
# 2580      1023         2  Chicken Bowl    $16.98
# 2771      1100         2  Chicken Bowl    $16.98
# ...

# %%
df.iloc[[5]]
# Out:
#    order_id  quantity     item_name  \
# 5         3         1  Chicken Bowl
#
#                                   choice_description item_price
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98

# %%
df.iloc[5:15]
# Out:
#     order_id  quantity             item_name  \
# 5          3         1          Chicken Bowl
# 6          3         1         Side of Chips
# 7          4         1         Steak Burrito
# 8          4         1      Steak Soft Tacos
# 9          5         1         Steak Burrito
# 10         5         1   Chips and Guacamole
# 11         6         1  Chicken Crispy Tacos
# 12         6         1    Chicken Soft Tacos
# 13         7         1          Chicken Bowl
# 14         7         1   Chips and Guacamole
#
#                                    choice_description item_price
# 5   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                 NaN     $1.69
# 7   [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8   [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9   [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
# 10                                                NaN     $4.45
# ...

# %%
x=df.iloc[:5,:-1]
x
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description
# 0                                                NaN
# 1                                       [Clementine]
# 2                                            [Apple]
# 3                                                NaN
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...

# %%
y=df.iloc[:5]['item_price']
y = y.to_frame()
y
# Out:
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98

# %%
x.join(y)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.item_price=df.item_price.apply(lambda x: float(x.replace('$','')))
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
df['total_price']=df['quantity']*df['item_price']
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  total_price
# 0                                                NaN        2.39         2.39
# 1                                       [Clementine]        3.39         3.39
# 2                                            [Apple]        3.39         3.39
# 3                                                NaN        2.39         2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98        33.96

# %%
np.sum(df['total_price'])
# Out:
# 39237.02

# %%
np.max(df['quantity'])
# Out:
# 15

# %%
df.groupby(df['item_name'])['quantity'].sum().sort_values(ascending=False)
# Out:
# item_name
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chips and Guacamole                      506
# Steak Burrito                            386
# Canned Soft Drink                        351
# Chips                                    230
# Steak Bowl                               221
# Bottled Water                            211
# Chips and Fresh Tomato Salsa             130
# Canned Soda                              126
# Chicken Salad Bowl                       123
# Chicken Soft Tacos                       120
# Side of Chips                            110
# Veggie Burrito                            97
# Barbacoa Burrito                          91
# Veggie Bowl                               87
# Carnitas Bowl                             71
# Barbacoa Bowl                             66
# Carnitas Burrito                          60
# Steak Soft Tacos                          56
# 6 Pack Soft Drink                         55
# ...

# %%
df.item_name.value_counts().count()
# Out:
# 50

# %%
df.item_name.nunique()
# Out:
# 50
